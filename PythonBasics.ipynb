# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohammad-Zahed-Hossen/Python/blob/main/PythonBasics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Basics

# %%
print("Hello world! This is my first code.")
# Out:
# Hello world! This is my first code.
